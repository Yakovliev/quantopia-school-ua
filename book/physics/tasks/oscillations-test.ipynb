# %% [markdown]
# # Механічні коливання. Самостійна робота
#
# ## Механічні коливання
#
# **Задача 1**
#
# Варіант 1. Механічний годинник для своєї роботи використовує коливання маятника, який здійснює 1800 коливань за 15 хвилин. Визначте період та частоту цих коливань.
#
# Варіант 2. Крила комара під час польоту здійснюють 12000 коливань за 20 секунд. Визначте період та частоту цих коливань.
#
# Варіант 3. Під час шторму невеличкий човен на хвилях здійснив 90 коливань вгору-вниз за 3 хвилини. Визначте період та частоту коливань човна.
#
# ---
#
# **Задача 2**
#
# Варіант 1. Комаха, що летить, робить 1200 змахів крилами за 4 секунди. Визначте період та частоту цих коливань.
#
# Варіант 2. Гойдалка в парку атракціонів здійснює 45 повних коливань за 90 секунд. Визначте період та частоту цих коливань.
#
# Варіант 3. Маятник настінного годинника здійснив 900 коливань за 15 хвилин. Визначте період та частоту цих коливань.
#
# ---
#
# **Задача 3**
#
# Варіант 1. Гілка дерева під дією вітру за 40 секунд здійснює 20 повних коливань. Амплітуда цих коливань становить 30 см. Визначте частоту та період коливань гілки.
#
# Варіант 2. Поршень у двигуні автомобіля на холостих обертах здійснює 200 повних коливань (вгору-вниз) за 10 секунд. Амплітуда його руху становить 4 см. Визначте частоту та період коливань поршня.
#
# Варіант 3. Струна гітари після щипка здійснює 880 повних коливань за 2 секунди. Амплітуда початкового коливання становить 3 мм. Визначте частоту та період коливань струни.
#
# ---
#
# **Задача 4**
#
# Варіант 1. Коливання точки на поверхні води описуються рівнянням: $x = 0.05 \cos(10\pi t)$, де всі величини вказані в СІ.
# 1. Чому дорівнює амплітуда коливань?
# 2. Визначте циклічну частоту.
# 3. Обчисліть період та частоту коливань.
#
# Варіант 2. Коливання вантажу, підвішеного на пружині, описуються рівнянням: $x = 0.1 \cos(5\pi t)$, де всі величини вказані в СІ.
# 1. Чому дорівнює амплітуда коливань?
# 2. Визначте циклічну частоту.
# 3. Обчисліть період та частоту коливань.
#
# Варіант 3. Рівняння коливань струни музичного інструменту має вигляд: $x = 0.001 \cos(880\pi t)$, де всі величини вказані в СІ.
# 1. Чому дорівнює амплітуда коливань?
# 2. Визначте циклічну частоту.
# 3. Обчисліть період та частоту звуку, який видає струна.
#
# ---
#
# **Задача 5**
#
# Варіант 1. Коливання вантажу, підвішеного на пружині, описуються рівнянням: $x = 0.05 \cos(20\pi t)$, де всі величини вказані в СІ.
# 1.  Чому дорівнює амплітуда коливань?
# 2.  Визначте циклічну частоту.
# 3.  Обчисліть період та частоту коливань вантажу.
#
# Варіант 2. Коливання напруги в побутовій електричній мережі описуються рівнянням, що має вигляд: $U = 311 \cos(100\pi t)$, де всі величини вказані в СІ.
# 1.  Чому дорівнює амплітуда коливань напруги?
# 2.  Визначте циклічну частоту.
# 3.  Обчисліть період та частоту змінного струму.
#
# Варіант 3. Коливання точки на поверхні води описуються рівнянням: $x = 0.01 \cos(20\pi t)$, де всі величини вказані в СІ.
# 1.  Чому дорівнює амплітуда коливань?
# 2.  Визначте циклічну частоту.
# 3.  Обчисліть період та частоту коливань точки на поверхні води.

# %% [markdown]
# ## Пружинний маятник
#
# **Задача 1**
#
# Варіант 1. Амортизатор у підвісці сучасного електромобіля можна змоделювати як пружинний маятник. Нехай маса, що припадає на один амортизатор, дорівнює 350 кг. Жорсткість пружини амортизатора становить 35 000 Н/м. Обчисліть період вільних коливань автомобіля на цій пружині після проїзду нерівності.
#
# Варіант 2. Амортизатор у підвісці сучасного електромобіля можна змоделювати як пружинний маятник. Нехай маса, що припадає на один амортизатор, дорівнює 450 кг. Жорсткість пружини амортизатора становить 45 000 Н/м. Обчисліть період вільних коливань автомобіля на цій пружині після проїзду нерівності.
#
# Варіант 3. Амортизатор у підвісці сучасного електромобіля можна змоделювати як пружинний маятник. Нехай маса, що припадає на один амортизатор, дорівнює 500 кг. Жорсткість пружини амортизатора становить 50 000 Н/м. Обчисліть період вільних коливань автомобіля на цій пружині після проїзду нерівності.
#
# ***
#
# **Задача 2**
#
# Варіант 1. На Міжнародній космічній станції (МКС) для вимірювання маси космонавтів в умовах невагомості використовують спеціальне крісло, що коливається на пружинах. Під час тренування космонавт сів у крісло, і система почала коливатися з періодом 2.0 с. Визначте масу космонавта, якщо сумарна жорсткість пружин крісла дорівнює 1200 Н/м. Масою крісла можна знехтувати.
#
# Варіант 2. На Міжнародній космічній станції (МКС) для вимірювання маси космонавтів в умовах невагомості використовують спеціальне крісло, що коливається на пружинах. Під час тренування космонавт сів у крісло, і система почала коливатися з періодом 3.0 с. Визначте масу космонавта, якщо сумарна жорсткість пружин крісла дорівнює 1800 Н/м. Масою крісла можна знехтувати.
#
# Варіант 3. На Міжнародній космічній станції (МКС) для вимірювання маси космонавтів в умовах невагомості використовують спеціальне крісло, що коливається на пружинах. Під час тренування космонавт сів у крісло, і система почала коливатися з періодом 2.8 с. Визначте масу космонавта, якщо сумарна жорсткість пружин крісла дорівнює 1550 Н/м. Масою крісла можна знехтувати.
#
# ***
#
# **Задача 3**
#
# Варіант 1. Фітнес-тренажер "силовий еспандер" складається з кількох пружин. Щоб розтягнути одну таку пружину на 30 см, потрібно прикласти силу 120 Н. 1. Знайдіть жорсткість цієї пружини. 2. Яким був би період коливань, якби до цієї пружини підвісили гирю масою 4 кг?
#
# Варіант 2. Фітнес-тренажер "силовий еспандер" складається з кількох пружин. Щоб розтягнути одну таку пружину на 10 см, потрібно прикласти силу 80 Н. 1. Знайдіть жорсткість цієї пружини. 2. Яким був би період коливань, якби до цієї пружини підвісили гирю масою 5 кг?
#
# Варіант 3. Фітнес-тренажер "силовий еспандер" складається з кількох пружин. Щоб розтягнути одну таку пружину на 25 см, потрібно прикласти силу 150 Н. 1. Знайдіть жорсткість цієї пружини. 2. Яким був би період коливань, якби до цієї пружини підвісили гирю масою 15 кг?
#
# ***
#
# **Задача 4**
#
# Варіант 1. Атракціон "банджі-джампінг". Людина масою 60 кг стрибає з мосту, використовуючи еластичний трос. У стані рівноваги, коли людина просто висить на тросі, трос розтягується на 10 м. Розрахуйте жорсткість тросу, вважаючи його ідеальною пружиною. Знайдіть період коливань людини на цьому тросі.
#
# Варіант 2. Атракціон "банджі-джампінг". Людина масою 70 кг стрибає з мосту, використовуючи еластичний трос. У стані рівноваги, коли людина просто висить на тросі, трос розтягується на 14 м. Розрахуйте жорсткість тросу, вважаючи його ідеальною пружиною. Знайдіть період коливань людини на цьому тросі.
#
# Варіант 3. Атракціон "банджі-джампінг". Людина масою 80 кг стрибає з мосту, використовуючи еластичний трос. У стані рівноваги, коли людина просто висить на тросі, трос розтягується на 16 м. Розрахуйте жорсткість тросу, вважаючи його ідеальною пружиною. Знайдіть період коливань людини на цьому тросі.
#
# ---

# %% [markdown]
# ## Математичний маятник
#
# **Задача 1**
#
# Варіант 1. Для розваги в парку атракціонів встановили гігантську гойдалку, яку можна вважати математичним маятником. Довжина тросів, на яких підвішене сидіння, становить 12 м. З яким періодом буде коливатися ця гойдалка при малих кутах відхилення?
#
# Варіант 2. Для розваги в парку атракціонів встановили гігантську гойдалку, яку можна вважати математичним маятником. Довжина тросів, на яких підвішене сидіння, становить 8 м. З яким періодом буде коливатися ця гойдалка при малих кутах відхилення?
#
# Варіант 3. Для розваги в парку атракціонів встановили гігантську гойдалку, яку можна вважати математичним маятником. Довжина тросів, на яких підвішене сидіння, становить 15 м. З яким періодом буде коливатися ця гойдалка при малих кутах відхилення?
#
# ***
#
# **Задача 2**
#
# Варіант 1. Під час будівельних робіт хмарочоса вантаж масою 1.5 тонни підвішений на сталевому тросі баштового крана довжиною 64 м. Коливання цього вантажу можна змоделювати як математичний маятник. Визначте період малих коливань вантажу. Вважайте, що прискорення вільного падіння дорівнює 10 $\text{м}/\text{с}^2$.
#
# Варіант 2. Під час будівельних робіт хмарочоса вантаж масою 2.5 тонни підвішений на сталевому тросі баштового крана довжиною 100 м. Коливання цього вантажу можна змоделювати як математичний маятник. Визначте період малих коливань вантажу. Вважайте, що прискорення вільного падіння дорівнює 10 $\text{м}/\text{с}^2$.
#
# Варіант 3. Під час будівельних робіт хмарочоса вантаж масою 3 тонни підвішений на сталевому тросі баштового крана довжиною 49 м. Коливання цього вантажу можна змоделювати як математичний маятник. Визначте період малих коливань вантажу. Вважайте, що прискорення вільного падіння дорівнює 10 $\text{м}/\text{с}^2$.
#
#
# **Задача 3**
#
# Варіант 1. Будівельний кран підіймає вантаж масою 1.5 тонни на тросі довжиною 25 м. Через порив вітру вантаж починає розгойдуватися як математичний маятник. Максимальна швидкість вантажу при проходженні положення рівноваги склала 1.2 м/с. Визначте повну механічну енергію коливань вантажу та максимальну висоту, на яку він підіймається відносно положення рівноваги.
#
# Варіант 2. Будівельний кран підіймає вантаж масою 2.5 тонни на тросі довжиною 15 м. Через порив вітру вантаж починає розгойдуватися як математичний маятник. Максимальна швидкість вантажу при проходженні положення рівноваги склала 2 м/с. Визначте повну механічну енергію коливань вантажу та максимальну висоту, на яку він підіймається відносно положення рівноваги.
#
# Варіант 3. Будівельний кран підіймає вантаж масою 3 тонни на тросі довжиною 30 м. Через порив вітру вантаж починає розгойдуватися як математичний маятник. Максимальна швидкість вантажу при проходженні положення рівноваги склала 1.8 м/с. Визначте повну механічну енергію коливань вантажу та максимальну висоту, на яку він підіймається відносно положення рівноваги.
#
# ***
#
# **Задача 4**
#
# Варіант 1. Майбутня місія на Марс планує дослідити місцеве прискорення вільного падіння за допомогою маятника. Яким буде період коливань маятника довжиною 2 м на Марсі, якщо відомо, що прискорення вільного падіння там становить приблизно 3.7 $\text{м}/\text{с}^2$?
#
# Варіант 2. Майбутня місія на Марс планує дослідити місцеве прискорення вільного падіння за допомогою маятника. Яким буде період коливань маятника довжиною 3 м на Марсі, якщо відомо, що прискорення вільного падіння там становить приблизно 3.7 $\text{м}/\text{с}^2$?
#
# Варіант 3. Майбутня місія на Марс планує дослідити місцеве прискорення вільного падіння за допомогою маятника. Яким буде період коливань маятника довжиною 4 м на Марсі, якщо відомо, що прискорення вільного падіння там становить приблизно 3.7 $\text{м}/\text{с}^2$?
