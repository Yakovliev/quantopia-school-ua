# %% [markdown]
# # Електромагнітні коливання та хвилі. Задачі

# %% [markdown]
# **Задача 1**
#
# Простий радіоприймач для прийому середніх хвиль використовує коливальний контур. Щоб налаштуватися на радіостанцію, яка веде мовлення на частоті 1000 кГц, у контурі використовують котушку з індуктивністю 250 мкГн.
# 1.  Який період електромагнітних коливань у контурі, коли він налаштований на цю станцію?
# 2.  Обчисліть ємність конденсатора, яку для цього необхідно встановити.
#
# Варіант 1. Простий радіоприймач для прийому середніх хвиль використовує коливальний контур. Щоб налаштуватися на радіостанцію, яка веде мовлення на частоті 800 кГц, у контурі використовують котушку з індуктивністю 300 мкГн.
# 1. Який період електромагнітних коливань у контурі, коли він налаштований на цю станцію?
# 2. Обчисліть ємність конденсатора, яку для цього необхідно встановити.
#
# Варіант 2. Простий радіоприймач для прийому середніх хвиль використовує коливальний контур. Щоб налаштуватися на радіостанцію, яка веде мовлення на частоті 1200 кГц, у контурі використовують котушку з індуктивністю 200 мкГн.
# 1. Який період електромагнітних коливань у контурі, коли він налаштований на цю станцію?
# 2. Обчисліть ємність конденсатора, яку для цього необхідно встановити.
#
# Варіант 3. Простий радіоприймач для прийому середніх хвиль використовує коливальний контур. Щоб налаштуватися на радіостанцію, яка веде мовлення на частоті 600 кГц, у контурі використовують котушку з індуктивністю 400 мкГн.
# 1. Який період електромагнітних коливань у контурі, коли він налаштований на цю станцію?
# 2. Обчисліть ємність конденсатора, яку для цього необхідно встановити.
#
# **Задача 2**
#
# Спалах у сучасному смартфоні працює завдяки розрядці конденсатора, який накопичує енергію. Уявімо, що в коливальному контурі, який моделює цю систему, ємність конденсатора становить 150 мкФ, і він заряджається до напруги 4 В.
# 1.  Який максимальний заряд накопичує конденсатор?
# 2.  Яка максимальна енергія електричного поля зберігається в контурі?
#
# Варіант 1. Спалах у сучасному смартфоні працює завдяки розрядці конденсатора, який накопичує енергію. Уявімо, що в коливальному контурі, який моделює цю систему, ємність конденсатора становить 200 мкФ, і він заряджається до напруги 5 В.
# 1. Який максимальний заряд накопичує конденсатор?
# 2. Яка максимальна енергія електричного поля зберігається в контурі?
#
# Варіант 2. Спалах у сучасному смартфоні працює завдяки розрядці конденсатора, який накопичує енергію. Уявімо, що в коливальному контурі, який моделює цю систему, ємність конденсатора становить 120 мкФ, і він заряджається до напруги 3.5 В.
# 1. Який максимальний заряд накопичує конденсатор?
# 2. Яка максимальна енергія електричного поля зберігається в контурі?
#
# Варіант 3. Спалах у сучасному смартфоні працює завдяки розрядці конденсатора, який накопичує енергію. Уявімо, що в коливальному контурі, який моделює цю систему, ємність конденсатора становить 250 мкФ, і він заряджається до напруги 3 В.
# 1. Який максимальний заряд накопичує конденсатор?
# 2. Яка максимальна енергія електричного поля зберігається в контурі?
#
# **Задача 3**
#
# Безконтактні RFID-мітки, які використовуються в магазинах для захисту товарів від крадіжки, містять у собі простий LC-контур. Припустимо, мітка розрахована на резонансну частоту 8.2 МГц, а індуктивність її котушки становить 3 мкГн. Обчисліть, якою має бути ємність конденсатора в цій мітці, щоб вона працювала на заданій частоті.
#
# Варіант 1. Безконтактні RFID-мітки, які використовуються в магазинах для захисту товарів від крадіжки, містять у собі простий LC-контур. Припустимо, мітка розрахована на резонансну частоту 13.56 МГц, а індуктивність її котушки становить 2 мкГн. Обчисліть, якою має бути ємність конденсатора в цій мітці, щоб вона працювала на заданій частоті.
#
# Варіант 2. Безконтактні RFID-мітки, які використовуються в магазинах для захисту товарів від крадіжки, містять у собі простий LC-контур. Припустимо, мітка розрахована на резонансну частоту 6.8 МГц, а індуктивність її котушки становить 4 мкГн. Обчисліть, якою має бути ємність конденсатора в цій мітці, щоб вона працювала на заданій частоті.
#
# Варіант 3. Безконтактні RFID-мітки, які використовуються в магазинах для захисту товарів від крадіжки, містять у собі простий LC-контур. Припустимо, мітка розрахована на резонансну частоту 10 МГц, а індуктивність її котушки становить 2.5 мкГн. Обчисліть, якою має бути ємність конденсатора в цій мітці, щоб вона працювала на заданій частоті.
#
# **Задача 4**
#
# Платформа для бездротової зарядки смартфона (стандарт Qi) створює змінне магнітне поле за допомогою коливального контуру. В одному з таких пристроїв індуктивність котушки дорівнює 10 мкГн, а ємність конденсатора - 400 нФ. Максимальна напруга на конденсаторі сягає 5 В. Знайдіть максимальне значення сили струму в котушці зарядного пристрою.
#
# **Задача 5**
#
# Коливання заряду на обкладках конденсатора в коливальному контурі, що є частиною електронного музичного інструмента, описуються рівнянням:
# $q(t) = 0.004 \cos(1000\pi t)$, де всі величини подано в одиницях СІ.
# Визначте:
# 1.  Амплітуду коливань заряду.
# 2.  Циклічну частоту коливань.
# 3.  Період коливань.
# 4.  Значення заряду на конденсаторі в момент часу t = 0.5 мс.
#
# **Задача 6**
#
# Інженер розробляє аудіофільтр (кросовер) для акустичної системи. Фільтр на основі LC-контуру налаштований на частоту $\nu$. Як інженеру потрібно змінити ємність конденсатора (збільшити чи зменшити і у скільки разів), щоб налаштувати контур на частоту $2\nu$, не змінюючи індуктивності котушки?
#
# **Задача 7**
#
# Повна енергія, накопичена в ідеальному коливальному контурі, дорівнює 200 мкДж.
# Знайдіть енергію електричного поля конденсатора та енергію магнітного поля котушки в момент, коли:
# 1.  Сила струму в котушці дорівнює половині свого максимального (амплітудного) значення.
# 2.  Напруга на конденсаторі дорівнює половині свого максимального (амплітудного) значення.
#
# **Задача 8**
#
# Радіочастотний контур у апараті МРТ (магнітно-резонансної томографії) генерує коливання, в яких заряд на конденсаторі змінюється за законом $q(t) = 2 \cdot 10^{-8} \cos(5 \cdot 10^{7} t)$ (усі величини в СІ). Ємність конденсатора в цьому контурі становить 50 пФ.
# 1.  Знайдіть індуктивність L котушки.
# 2.  Запишіть рівняння залежності напруги від часу $u(t)$.
# 3.  Запишіть рівняння залежності сили струму від часу $i(t)$.
#
# **Задача 9**
#
# Розглянемо ідеальний коливальний контур. У початковий момент часу (t=0) конденсатор повністю заряджений. Знайдіть найменший момент часу $t > 0$ (виразіть його через період коливань T), коли енергія магнітного поля котушки буде в 3 рази більшою за енергію електричного поля конденсатора.
#
# **Задача 10**
#
# Студент на лабораторній роботі зібрав ідеальний коливальний контур з котушки індуктивністю 25 мГн та конденсатора ємністю 10 мкФ. Він зарядив конденсатор, під'єднавши його до джерела з напругою 12 В.
# 1.  Обчисліть період вільних електромагнітних коливань у контурі.
# 2.  Знайдіть максимальну силу струму, що виникне в котушці.
# 3.  Запишіть рівняння зміни напруги на конденсаторі $u(t)$, вважаючи, що в момент t=0 напруга була максимальною.

# %% [markdown]
# ## Змінний струм
#
# **Задача 1**
#
# Напруга в побутовій електромережі України змінюється за законом, близьким до гармонічного. Рівняння для миттєвої ЕРС має вигляд:
# $$ \varepsilon(t) = 311 \sin(100\pi t) $$
# де всі величини виражені в одиницях СІ. Визначте:
# 1.  Амплітудне значення ЕРС.
# 2.  Циклічну частоту коливань.
# 3.  Стандартну частоту змінного струму в мережі (в герцах).
# 4.  Період коливань.
#
# **Задача 2**
#
# Ротор генератора на Дніпровській ГЕС має 32 пари магнітних полюсів ($p=32$). Щоб виробляти змінний струм стандартної частоти 50 Гц, цей ротор має обертатися з певною швидкістю.
# 1.  З якою швидкістю (в обертах за секунду) має обертатися ротор цього генератора?
# 2.  Виразіть цю швидкість в обертах за хвилину (об/хв).
#
# **Задача 3**
#
# Для живлення автономного наукового обладнання в польових умовах використовується невеликий вітрогенератор. Його ротор створює магнітне поле з індукцією 0.8 Тл. В обмотці статора, що має 150 витків, індукується ЕРС. Площа кожного витка становить 0.02 м². Ротор обертається зі швидкістю, що забезпечує генерацію струму з частотою 50 Гц. Розрахуйте амплітудне значення ЕРС, що виробляється цим генератором.
#
# Варіант 1. Для живлення автономного наукового обладнання в польових умовах використовується невеликий вітрогенератор. Його ротор створює магнітне поле з індукцією 0.6 Тл. В обмотці статора, що має 200 витків, індукується ЕРС. Площа кожного витка становить 0.025 м². Ротор обертається зі швидкістю, що забезпечує генерацію струму з частотою 60 Гц. Розрахуйте амплітудне значення ЕРС, що виробляється цим генератором.
#
# Варіант 2. Для живлення автономного наукового обладнання в польових умовах використовується невеликий вітрогенератор. Його ротор створює магнітне поле з індукцією 1.1 Тл. В обмотці статора, що має 120 витків, індукується ЕРС. Площа кожного витка становить 0.015 м². Ротор обертається зі швидкістю, що забезпечує генерацію струму з частотою 40 Гц. Розрахуйте амплітудне значення ЕРС, що виробляється цим генератором.
#
# Варіант 3. Для живлення автономного наукового обладнання в польових умовах використовується невеликий вітрогенератор. Його ротор створює магнітне поле з індукцією 0.9 Тл. В обмотці статора, що має 250 витків, індукується ЕРС. Площа кожного витка становить 0.03 м². Ротор обертається зі швидкістю, що забезпечує генерацію струму з частотою 55 Гц. Розрахуйте амплітудне значення ЕРС, що виробляється цим генератором.
#
# **Задача 4**
#
# Уявімо ідеальний генератор, обмотка якого складається з 200 витків площею 100 см² кожен. Обмотка обертається з кутовою швидкістю 314 рад/с в однорідному магнітному полі з індукцією 1.2 Тл. До виходів генератора підключили потужний прожектор, який можна вважати активним навантаженням з опором 50 Ом. Внутрішнім опором генератора можна знехтувати.
# 1.  Знайдіть амплітудне значення ЕРС генератора.
# 2.  Розрахуйте амплітудне значення сили струму в колі прожектора.
# 3.  Запишіть рівняння залежності миттєвої сили струму від часу $i(t)$, вважаючи, що в початковий момент часу ЕРС дорівнювала нулю.
#
#
# Варіант 1. Уявімо ідеальний генератор, обмотка якого складається з 250 витків площею 120 см² кожен. Обмотка обертається з кутовою швидкістю 157 рад/с в однорідному магнітному полі з індукцією 1.0 Тл. До виходів генератора підключили потужний прожектор, який можна вважати активним навантаженням з опором 40 Ом. Внутрішнім опором генератора можна знехтувати.
# 1. Знайдіть амплітудне значення ЕРС генератора.
# 2. Розрахуйте амплітудне значення сили струму в колі прожектора.
# 3. Запишіть рівняння залежності миттєвої сили струму від часу $i(t)$, вважаючи, що в початковий момент часу ЕРС дорівнювала нулю.
#
# Варіант 2. Уявімо ідеальний генератор, обмотка якого складається з 180 витків площею 80 см² кожен. Обмотка обертається з кутовою швидкістю 300 рад/с в однорідному магнітному полі з індукцією 1.5 Тл. До виходів генератора підключили потужний прожектор, який можна вважати активним навантаженням з опором 60 Ом. Внутрішнім опором генератора можна знехтувати.
# 1. Знайдіть амплітудне значення ЕРС генератора.
# 2. Розрахуйте амплітудне значення сили струму в колі прожектора.
# 3. Запишіть рівняння залежності миттєвої сили струму від часу $i(t)$, вважаючи, що в початковий момент часу ЕРС дорівнювала нулю.
#
# Варіант 3. Уявімо ідеальний генератор, обмотка якого складається з 300 витків площею 150 см² кожен. Обмотка обертається з кутовою швидкістю 200 рад/с в однорідному магнітному полі з індукцією 0.8 Тл. До виходів генератора підключили потужний прожектор, який можна вважати активним навантаженням з опором 75 Ом. Внутрішнім опором генератора можна знехтувати.
# 1. Знайдіть амплітудне значення ЕРС генератора.
# 2. Розрахуйте амплітудне значення сили струму в колі прожектора.
# 3. Запишіть рівняння залежності миттєвої сили струму від часу $i(t)$, вважаючи, що в початковий момент часу ЕРС дорівнювала нулю.
#
# **Задача 5**
#
# До джерела змінного струму, ЕРС якого змінюється за законом $\varepsilon(t) = 120 \sin(50\pi t)$, під'єднано активний опір.
# 1.  Яким буде миттєве значення ЕРС в момент часу $t = 1/300$ с?
# 2.  Через який мінімальний проміжок часу від початку коливань ($t=0$) ЕРС вперше досягне свого максимального значення?
#
# Варіант 1. До джерела змінного струму, ЕРС якого змінюється за законом $\varepsilon(t) = 150 \sin(100\pi t)$, під'єднано активний опір.
# 1. Яким буде миттєве значення ЕРС в момент часу $t = 1/600$ с?
# 2. Через який мінімальний проміжок часу від початку коливань ($t=0$) ЕРС вперше досягне свого максимального значення?
#
# Варіант 2. До джерела змінного струму, ЕРС якого змінюється за законом $\varepsilon(t) = 220 \sin(60\pi t)$, під'єднано активний опір.
# 1. Яким буде миттєве значення ЕРС в момент часу $t = 1/240$ с?
# 2. Через який мінімальний проміжок часу від початку коливань ($t=0$) ЕРС вперше досягне свого максимального значення?
#
# Варіант 3. До джерела змінного струму, ЕРС якого змінюється за законом $\varepsilon(t) = 100 \sin(40\pi t)$, під'єднано активний опір.
# 1. Яким буде миттєве значення ЕРС в момент часу $t = 1/120$ с?
# 2. Через який мінімальний проміжок часу від початку коливань ($t=0$) ЕРС вперше досягне свого максимального значення?
