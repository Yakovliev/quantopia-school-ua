# %% [markdown]
# # Кінематика. Задачі

# %% [markdown]
# ## Рівномірний рух
#
# **Задача 1**: Дрон-кур'єр
#
# Квадрокоптер вилетів з бази, доставив пакунок на відстань 1.2 км по прямій і повернувся назад на базу. Визначте шлях, пройдений дроном, та модуль його переміщення за весь час польоту.
#
# **Задача 2**
#
# Автомобіль проїхав по прямій дорозі 3 км на схід, а потім повернув і проїхав 4 км на північ. Визначити пройдену відстань (шлях) та модуль переміщення.
#
# **Задача 3**
#
# Перевести км/год в м/с або навпаки:
# * 10 м/с
# * 30 м/с
# * 36 км/год
# * 72 км/год
# * 18 км/год
# * 54 км/год
# * перша космічна швидкість: 28 440 км/год
#
# **Задача 4**: Квадрокоптер і доставка
#
# Квадрокоптер служби доставки вилетів зі складу, пролетів по прямій 800 метрів до будинку клієнта, передав посилку і тим самим маршрутом повернувся назад на склад. Весь політ тривав 4 хвилини. Визначте:
# 1. Шлях, який подолав квадрокоптер.
# 2. Модуль його переміщення за весь час польоту.
# 3. Середню швидкість польоту (на основі шляху).
#
# **Задача 5**: Автопілот у Tesla
#
# Автомобіль Tesla, рухаючись на автопілоті по прямому відрізку шосе зі сталою швидкістю 90 км/год, перебував у точці з координатою $x_0 = 10$ км (відносно початку відліку - міста). Якою буде його координата через 2 години руху в тому ж напрямку? Запишіть рівняння руху автомобіля.
#
# **Задача 6**: Рух на травелаторі в аеропорту
#
# Пасажир іде по рухомій доріжці (травелаторі) в аеропорту. Його швидкість відносно доріжки становить 1 м/с, а швидкість самої доріжки відносно підлоги термінала - 1.5 м/с. Який шлях подолає пасажир відносно підлоги термінала за 2 хвилини, якщо він рухається:
# 1. У напрямку руху доріжки?
# 2. Проти напрямку руху доріжки?
#
# **Задача 7**: Хто швидший: дрон чи велосипедист?
#
# Спортивний дрон летить зі швидкістю 20 м/с. Професійний велогонщик їде зі швидкістю 75 км/год. Порівняйте їхні швидкості, попередньо перевівши одну з них в одиниці іншої. Хто з них рухається швидше?
#
# **Задача 8**: GPS-трекер кур'єра
#
# Кур'єр на велосипеді виїхав з офісу і, згідно з даними GPS-трекера, проїхав 400 метрів на схід, а потім повернув і проїхав 300 метрів на північ до першого пункту доставки.
# 1. Зобразіть на малюнку траєкторію руху та вектор переміщення.
# 2. Обчисліть шлях, який подолав кур'єр.
# 3. Обчисліть модуль переміщення кур'єра (тобто, на якій відстані по прямій від офісу він опинився).
#
# **Задача 9**: Зустріч роботів на складі Amazon
#
# Два автоматизовані роботи-візки рухаються назустріч один одному по прямому довгому коридору складу довжиною 200 м. Перший робот стартує з нульової позначки зі швидкістю 2 м/с. Другий робот стартує одночасно з ним з позначки 200 м зі швидкістю 3 м/с.
# 1. Напишіть рівняння руху для кожного робота (взявши за напрямок осі ОХ рух першого робота).
# 2. Знайдіть час, через який роботи зустрінуться.
# 3. Знайдіть координату їхньої зустрічі.
#
# **Задача 10**: Маневри міського дрона
#
# Дрон-розвідник для моніторингу трафіку злетів з даху хмарочоса, пролетів 600 м на схід, потім 400 м на північ, після чого розвернувся і пролетів 300 м на захід, де й завис над перехрестям.
# 1. Який загальний шлях подолав дрон?
# 2. Знайдіть модуль кінцевого переміщення дрона відносно точки старту.
#
# **Задача 11**
#
# Людина їде на електросамокаті до університету. Відстань у 1.8 км вона долає за 5 хвилин. Вважаючи рух рівномірним, визначте швидкість самоката в м/с.
#
# **Задача 12**
#
# Автомобіль, рухаючись рівномірно і прямолінійно по шосе, знаходився в точці з координатою $x_0 = 15$ км. Через 10 хвилин його координата стала x = 35 км. Напишіть рівняння руху автомобіля $x(t)$ і визначте, де він буде через пів години після початку спостереження. (Вісь ОХ спрямована вздовж шосе).
#
# **Задача 13**: Рух на ескалаторі
#
# Людина йде по ескалатору в торговому центрі. Швидкість руху ескалатора відносно підлоги становить 0.5 м/с, а швидкість людини відносно ескалатора - 1 м/с. Знайдіть швидкість людини відносно підлоги у двох випадках:
# 1. Людина йде у напрямку руху ескалатора.
# 2. Людина йде проти руху ескалатора.
#
# **Задача 14**: Фітнес-трекер і пробіжка
#
# Спортсмен пробіг 5 кіл на стандартному 400-метровому стадіоні за 10 хвилин, повернувшись у точку старту. Його фітнес-трекер зафіксував усі дані. Визначте:
# 1. Пройдений шлях спортсмена.
# 2. Його переміщення за весь час бігу.
# 3. Середню шляхову швидкість спортсмена в м/с.
# 4. Середню векторну швидкість (швидкість переміщення).
#
# **Задача 15**: Доставка за допомогою дрона
#
# Дрон-кур'єр доставляє посилку. Перші 2 км шляху він пролетів зі швидкістю 15 м/с, після чого через сильний вітер знизив швидкість до 10 м/с і дрон пролетів ще 1 км. Знайдіть середню шляхову швидкість дрона на всьому шляху.
#
# **Задача 16**: Зустріч роботів-кур'єрів
#
# З двох складів, відстань між якими 600 м, одночасно назустріч один одному виїхали два роботи-кур'єри. Рівняння руху першого робота $x_1(t) = 1.5t$, а другого - $x_2(t) = 600 - 2.5t$. (Вісь ОХ спрямована від першого складу до другого).
# 1. Опишіть рух кожного робота (початкова координата, швидкість, напрямок).
# 2. Знайдіть час і місце їхньої зустрічі.
# 3. Побудуйте графіки руху $x(t)$ для обох роботів в одній системі координат.
#
# **Задача 17**: Обгін на автостраді
#
# Два автомобілі їдуть по прямій автостраді в одному напрямку. Швидкість першого автомобіля 90 км/год, а другого - 108 км/год. Яка відносна швидкість другого автомобіля відносно першого? Якщо в початковий момент часу відстань між ними була 200 м, через який час другий автомобіль наздожене перший?
#
# **Задача 18**: Марсохід "Perseverance"
#
# Марсохід рухається по поверхні Марса. Рівняння його руху вздовж осі ОХ має вигляд $x(t) = 10 - 0.2t$, а вздовж осі OY - $y(t) = -5 + 0.15t$ (усі величини в СІ).
# 1. Визначте початкові координати марсохода.
# 2. Знайдіть проекції його швидкості $v_x$ та $v_y$.
# 3. Знайдіть модуль його миттєвої швидкості (підказка: використовуйте теорему Піфагора для проекцій швидкості).
# 4. Напишіть рівняння траєкторії руху $y(x)$.
#
# ---

# %% [markdown]
# ## Рівноприскорений прямолінійний рух
#
# **Задача 1**
#
# Електросамокат рушає з місця і, рухаючись прямолінійно, за 4 секунди розвиває швидкість 7 м/с. З яким прискоренням рухався електросамокат?
#
# **Задача 2**
#
# Відео-блогер запускає свій квадрокоптер вертикально вгору зі стану спокою. Прискорення дрона становить 2 $\text{м}/\text{с}^2$. Яку висоту набере дрон за перші 5 секунд польоту?
#
# **Задача 3**
#
# Під час тест-драйву електромобіль розганяється зі стану спокою з постійним прискоренням 4 $\text{м}/\text{с}^2$. Яку швидкість матиме автомобіль, проїхавши перші 50 метрів?
#
# **Задача 4**
#
# Квадрокоптер, що доставляє посилку, летів горизонтально зі швидкістю 10 м/с. Оператор дав команду на прискорення, і дрон почав рухатись із прискоренням 0.5 $\text{м}/\text{с}^2$. Якою буде швидкість дрона через 10 секунд після початку прискорення?
#
# **Задача 5**
# Система екстреного гальмування безпілотного автомобіля, що рухався зі швидкістю 72 км/год, спрацювала, і автомобіль зупинився, пройшовши шлях 40 метрів. Визначте прискорення автомобіля під час гальмування та час, який для цього знадобився.
#
# **Задача 6**
# Космічний апарат, що рухається у відкритому космосі зі швидкістю 200 м/с, вмикає на 1 хвилину маневрові двигуни, які створюють прискорення 0.2 $\text{м}/\text{с}^2$ у напрямку руху. Який шлях подолає апарат за час роботи двигунів?
#
# **Задача 7**
#
# Швидкісний ліфт у хмарочосі починає рух з першого поверху і перші 3 секунди рухається з прискоренням 2 $\text{м}/\text{с}^2$, після чого їде з постійною швидкістю. На якій висоті буде ліфт через 3 секунди після старту, і якої швидкості він досягне? На якій висоті буде ліфт через 5 секунд після старту.
#
# **Задача 8**
# Зі складу, розташованого на прямому шосе, виїжджає перший робот-кур'єр зі швидкістю 3 м/с. Через 10 секунд слідом за ним зі складу виїжджає другий робот, який рухається з прискоренням 0.4 $\text{м}/\text{с}^2$. Через який час і на якій відстані від складу другий робот наздожене першого?
#
# **Задача 9**
#
# Посадковий модуль входить в атмосферу Марса і починає гальмувати. На останній ділянці гальмування довжиною 120 м його швидкість зменшилася з 50 м/с до 10 м/с. Вважаючи рух на цій ділянці рівносповільненим, знайдіть прискорення модуля та час, за який він пройшов цю ділянку.
#
# **Задача 10**
#
# Автомобіль, оснащений антиблокувальною системою (ABS), рухається по прямій дорозі зі швидкістю 72 км/год. Водій помічає перешкоду і починає екстрене гальмування. Гальмівний шлях автомобіля склав 20 метрів.
# 1. З яким прискоренням (за модулем) гальмував автомобіль?
# 2. Скільки часу тривало гальмування?
#
# **Задача 11**
#
# Зі складу, що знаходиться в точці з координатою x=0, виїжджає робот-кур'єр і рухається рівноприскорено з прискоренням 0.4 $\text{м}/\text{с}^2$. Одночасно з ним із пункту видачі з координатою $x=150$ м назустріч виїжджає інший робот-кур'єр, який рухається рівномірно зі швидкістю 5 м/с.
# 1. Запишіть рівняння руху $x(t)$ для обох роботів.
# 2. Знайдіть час та координату їхньої зустрічі.
#
# **Задача 12**
#
# Безпілотний автомобіль рухається зі швидкістю 20 м/с. Бортовий комп'ютер виявляє перешкоду на відстані 55 м і через 0.5 секунди (час на обробку даних) активує гальмівну систему, яка забезпечує прискорення -5 $\text{м}/\text{с}^2$.
# Запитання: Чи встигне автомобіль зупинитися перед перешкодою? Підтвердьте розрахунками. (Підказка: загальний гальмівний шлях складається зі шляху, пройденого за час реакції, та шляху, пройденого під час гальмування).
#
# **Задача 13**
#
# Смартфон випадково випадає з балкона 10-го поверху, що знаходиться на висоті 30 метрів. Скільки часу триватиме падіння і якою буде швидкість смартфона в момент удару об землю? Опором повітря знехтувати, прискорення вільного падіння вважати рівним 9.8 $\text{м}/\text{с}^2$.
#
# ---

# %% [markdown]
# ## Рух під дією сили тяжіння
#
# Для спрощення обчислень використовуйте $g \approx 10 \text{ м}/\text{с}^2$, якщо в задачі не вказано інше значення.
#
# **Задача 1**
#
# Під час зйомки відео для TikTok з балкона, розташованого на висоті 20 метрів, у людинки випадково випадає з рук смартфон.
# 1. Скільки часу смартфон буде падати до землі?
# 2. Якою буде його швидкість в момент удару об землю?
#
# **Задача 2**
#
# Маленький квадрокоптер злітає вертикально вгору з початковою швидкістю 15 м/с. Уявімо, що одразу після старту його двигуни вимкнулись. На яку максимальну висоту він зможе піднятися за інерцією?
#
# **Задача 3**
# Кур'єрський дрон летить строго горизонтально на висоті 45 метрів зі швидкістю 12 м/с. У певний момент він скидає невелику посилку. На якій горизонтальній відстані від точки скидання посилка приземлиться?
#
# **Задача 4**
#
# Персонаж у відеогрі здійснює стрибок з початковою швидкістю 10 м/с під кутом $60^\circ$ до горизонту. Скільки ігрового часу персонаж перебуватиме у повітрі?
#
# **Задача 5**
#
# Спортсмен стрибає у воду з 5-метрової вишки. Яку швидкість він матиме в момент торкання води, якщо його початкова швидкість у вертикальному напрямку була рівна нулю?
#
# **Задача 6**
#
# Квадрокоптер служби доставки летить строго горизонтально на висоті 45 м зі швидкістю 15 м/с. У певний момент він скидає посилку. На якій горизонтальній відстані від точки скидання приземлиться посилка?
#
# **Задача 7**
#
# Гравець у гольф завдає удару по м'ячу, надаючи йому початкової швидкості 30 м/с під кутом $45^\circ$ до горизонту. На яку максимальну відстань полетить м'яч? (кут $45^\circ$ якраз і забезпечує максимальну дальність польоту).
#
# **Задача 8**
#
# Промисловий альпініст, перебуваючи на висоті 30 м, випадково впускає гайковий ключ. У цей же самий момент його напарник, що стоїть на землі прямо під ним, кидає йому вертикально вгору викрутку з початковою швидкістю 20 м/с. На якій висоті предмети зустрінуться?
#
# **Задача 9**
#
# Спортсмен тренується на симуляторі для гольфу. Він виконує два удари з однаковою початковою швидкістю 40 м/с. Перший удар – під кутом 30° до горизонту, другий – під кутом 60°.
# 1. Порівняйте дальності польоту м'яча в обох випадках. Зробіть висновок.
# 2. Порівняйте максимальні висоти підйому м'яча. Поясніть різницю.
#
# **Задача 10**
#
# З дослідницького літака, що летить горизонтально на висоті 500 м, скидають метеозонд. Відомо, що за час падіння він пролетів по горизонталі 400 м. Знайдіть швидкість літака, а також модуль та напрямок (кут до горизонту) швидкості зонда в момент його приземлення.
#
#
# **Задача 11**
#
# В лабораторії для тестування матеріалів з великої висоти в вакуумній камері скидають зразок. Високошвидкісна камера фіксує, що за останню секунду свого падіння зразок пролетів 35 метрів. З якої висоти його було скинуто?
#
# **Задача 12**
#
# Рятувальний дрон повинен доставити пакунок з ліками людям, які опинилися заблокованими на даху будинку. Дрон підлітає до будинку на висоті 40 м і перебуває на відстані 30 м від краю даху. Висота даху – 20 м. З якою горизонтальною швидкістю дрон має випустити пакунок, щоб той точно приземлився на край даху?
#
# **Задача 13**
#
# Волейболіст виконує подачу, вдаряючи по м'ячу на висоті 2.5 м над землею. Він надає м'ячу швидкості 18 м/с під кутом $30^\circ$ до горизонту. Волейбольна сітка має висоту 2.43 м і знаходиться на відстані 9 м від гравця. Чи перелетить м'яч сітку? Якщо так, то на якій висоті над нею?
#
# ---

# %% [markdown]
# ## Рівномірний рух по колу
#
# **Задача 1**
#
# Жорсткий диск (HDD) у комп'ютері обертається зі сталою частотою 7200 обертів за хвилину.
# 1.  Визначте обертову частоту диска в герцах (Гц).
# 2.  Знайдіть період обертання диска.
#
# **Задача 2**
#
# Пропелер сучасного квадрокоптера для аерофотозйомки обертається з частотою 3000 обертів за хвилину (об/хв).
# 1.  Переведіть цю частоту в одиниці СІ (об/с, або Гц).
# 2.  Визначте період обертання пропелера.
#
# **Задача 3**
#
# Барабан сучасної пральної машини під час віджиму робить 1600 обертів за 2 хвилини. Вважаючи цей рух рівномірним, визначте:
# 1.  Період обертання барабана.
# 2.  Обертову частоту.
#
# **Задача 4**
#
# Лопать квадрокоптера має довжину 12 см. Під час польоту вона обертається з частотою 100 Гц. Знайдіть лінійну швидкість точки, що знаходиться на самому кінці лопаті.
#
# **Задача 5**
#
# Автомобіль рухається по круговій розв'язці, радіус якої 30 м. Він проїжджає чверть кола за 5 секунд. Яка лінійна швидкість автомобіля? Яке доцентрове прискорення автомобіля?
#
# **Задача 6**
#
# Лопать вітрогенератора сучасної вітрової електростанції має довжину 60 м. Під час роботи вона робить один повний оберт за 4 секунди.
# 1.  Визначте кутову швидкість обертання лопаті.
# 2.  Знайдіть лінійну швидкість точки, що знаходиться на самому кінчику лопаті.
# 3.  Розрахуйте доцентрове прискорення цієї точки.
#
# **Задача 7**
#
# Міжнародна космічна станція (МКС) обертається навколо Землі по коловій орбіті на висоті приблизно 400 км. Період її обертання становить близько 92 хвилини. Радіус Землі вважайте рівним 6400 км.
# 1.  Яка лінійна швидкість МКС на орбіті?
# 2.  Яка кутова швидкість її руху?
#
# **Задача 8**
#
# Лопать сучасної вітрової турбіни має довжину 60 метрів. Кінчик лопаті рухається з лінійною швидкістю 75 м/с.
# 1.  З яким періодом обертається колесо вітрової турбіни?
# 2.  Яке доцентрове прискорення відчуває кінчик лопаті?
#
# **Задача 9**
#
# Безпілотний автомобіль проходить випробування на круговому треку радіусом 100 м. Системи безпеки розраховані так, що доцентрове прискорення не повинно перевищувати 8 $\text{м}/\text{с}^2$ для комфорту пасажирів.
# 1.  Яку максимальну лінійну швидкість може розвинути автомобіль на цьому треку?
# 2.  Якою буде його кутова швидкість при цій швидкості?
#
# **Задача 10**
#
# Барабан сучасної пральної машини має діаметр 50 см. Під час режиму віджиму він досягає обертової частоти 1200 об/хв.
# 1.  Яка кутова швидкість барабана в рад/с?
# 2.  З яким доцентровим прискоренням рухається білизна, притиснута до стінок барабана?
# 3.  Порівняйте це прискорення із прискоренням вільного падіння ($g = 9.8 \text{ м}/\text{с}^2$). У скільки разів воно більше?
#
# **Задача 11**
#
# Колесо електромобіля має радіус 35 см. Автомобіль рухається по прямій дорозі зі сталою швидкістю 72 км/год. Вважаючи, що колесо не проковзує, визначте:
# 1.  Лінійну швидкість точки на ободі колеса відносно осі обертання.
# 2.  Кутову швидкість обертання колеса.
# 3.  Обертову частоту колеса в об/с.
#
# **Задача 12**
#
# Інженери проєктують космічну станцію у формі тора (кільця) радіусом 180 м для створення штучної гравітації, рівної земній ($a = 9.8 \text{ м}/\text{с}^2$), за рахунок обертання.
# 1.  З якою кутовою швидкістю (в рад/с) має обертатися станція, щоб доцентрове прискорення на її зовнішньому краю дорівнювало $9.8 \text{ м}/\text{с}^2$?
# 2.  Якою буде лінійна швидкість житлових модулів на зовнішньому краю станції?
# 3.  Яке доцентрове прискорення відчуватиме космонавт, що працює в лабораторії, розташованій на відстані 90 м від осі обертання (тобто на половині радіуса)?
#
# **Задача 13**
#
# На колесо велосипеда діаметром 70 см встановили два датчики: один на ободі, а інший — на спиці на півдорозі від центру до обода. Велосипед їде зі сталою швидкістю 18 км/год.
# 1.  Знайдіть кутову швидкість обертання колеса.
# 2.  Обчисліть доцентрове прискорення для кожного з датчиків.
# 3.  У скільки разів відрізняються їхні прискорення?
#
# **Задача 14**
#
# Інженери проектують космічну станцію у формі кільця (тора) для створення штучної гравітації. Щоб умови були комфортними для людей, доцентрове прискорення на підлозі (зовнішньому радіусі кільця) має дорівнювати прискоренню вільного падіння на Землі ($a = 9.8$ $\text{м}/\text{с}^2$). Водночас, щоб уникнути запаморочення у мешканців, станція не повинна обертатися швидше, ніж 2 оберти за хвилину.
# 1.  Яку максимальну кутову швидкість (в рад/с) може мати станція?
# 2.  Яким має бути мінімальний радіус такої космічної станції, щоб задовольнити обидві умови?

# %% [markdown]
# ## Закони Ньютона
#
# **Задача 1**
#
# Сучасний квадрокоптер для доставки важить 4 кг. Щоб вертикально піднятися вгору, його двигуни повинні створити силу тяги, більшу за силу тяжіння. Припустимо, що сумарна сила тяги двигунів становить 60 Н, а сила тяжіння — 40 Н.
# 1.  Знайдіть рівнодійну силу, що діє на квадрокоптер під час зльоту.
# 2.  Обчисліть прискорення, з яким квадрокоптер починає підніматися.
#
# **Задача 2**
#
# На краш-тесті автомобіль масою 1500 кг зупиняється, врізавшись у перешкоду. Датчики показують, що в момент удару рівнодійна сила, яка діяла на автомобіль, дорівнювала 300000 Н. Якого прискорення (за модулем) зазнав автомобіль у цей момент?
#
# **Задача 3**
#
# Смартфон масою 200 г випадково падає з ваших рук. Під час падіння він притягується до Землі.
# 1.  З якою силою Земля притягує смартфон? (Вважайте, що прискорення вільного падіння дорівнює $g = 10 \text{ м}/\text{с}^2$).
# 2.  Згідно з третім законом Ньютона, смартфон також притягує до себе Землю. З якою силою смартфон притягує Землю?
# 3.  Маса Землі приблизно дорівнює $6 \cdot 10^{24}$ кг. Якого прискорення надає Землі сила притягання смартфона? Порівняйте це прискорення з прискоренням смартфона і поясніть, чому ми не помічаємо руху Землі.
#
# **Задача 4**
#
# Ліфт у сучасному хмарочосі масою 800 кг починає рух вгору зі стану спокою і за 3 секунди досягає швидкості 6 м/с. Рух вважайте рівноприскореним.
# 1.  Знайдіть прискорення ліфта.
# 2.  Обчисліть рівнодійну силу, яка надає ліфту цього прискорення.
# 3.  Знайдіть силу натягу троса, що піднімає ліфт (сила тяжіння, що діє на ліфт, дорівнює 8000 Н).
#
# **Задача 5**
#
# Двоє космонавтів у відкритому космосі, де немає тертя та опору, вирішили перевірити закони фізики. Перший космонавт масою 80 кг відштовхується від другого, масою 100 кг. У момент поштовху перший космонавт набуває прискорення 0.5 $\text{ м}/\text{с}^2$.
# 1.  Яку силу приклав перший космонавт до другого?
# 2.  Якого прискорення набув другий космонавт?
#
# **Задача 6**
#
# Кур'єр на електросамокаті масою 100 кг (разом із самокатом) рухається зі швидкістю 18 км/год. Він помічає перешкоду і починає гальмувати, зупиняючись за 2.5 секунди.
# 1.  Переведіть початкову швидкість у м/с.
# 2.  Знайдіть прискорення самоката під час гальмування (не забудьте про його напрямок).
# 3.  Визначте модуль гальмівної сили, що діяла на кур'єра із самокатом.
#
# **Задача 7**
#
# Інженер тестує новий іонний двигун для космічного зонда. Зонд масою 500 кг перебуває у глибокому космосі, де зовнішніми силами можна знехтувати.
# 1.  Перший тест: двигун працює в номінальному режимі, створюючи тягу 0.5 Н. Якого прискорення набуває зонд? Яку швидкість він набере за 24 години роботи двигуна?
# 2.  Другий тест: інженер вмикає форсажний режим, і прискорення зонда зростає до 0.003 $\text{ м}/\text{с}^2$. Яку силу тяги створює двигун у цьому режимі?
# 3.  Уявіть, що для корекції курсу одночасно вмикаються два однакові двигуни, розташовані під кутом 90° один до одного, кожен із силою тяги 0.5 Н. Яким буде модуль рівнодійної сили, що діє на зонд?

# %% [markdown]
# ## Закон всесвітнього тяжіння
#
# **Задача 1**
#
# Уявіть, що два новітні електропікапи Tesla Cybertruck, масою 3000 кг кожен, припарковані так, що відстань між їхніми центрами мас становить 4 метри. Обчисліть силу гравітаційного притягання між ними. Порівняйте цю силу із силою, з якою Земля притягує один із цих автомобілів.
#
# **Задача 2**
# Міжнародна космічна станція (МКС) обертається на висоті приблизно 400 км над поверхнею Землі. Маса станції становить близько 450 000 кг.
# 1. Яка сила тяжіння діє на МКС з боку Землі на цій висоті?
# 2. Чому астронавти на борту перебувають у стані невагомості, якщо сила тяжіння є такою значною?
#
# (Для розрахунків візьміть масу Землі $M_З = 6 \cdot 10^{24}$ кг, радіус Землі $R_З = 6400$ км, $G = 6.67 \cdot 10^{-11} \frac{\text{Н} \cdot \text{м}^2}{\text{кг}^2}$).
#
# **Задача 3**
#
# Марсохід "Perseverance" працює на поверхні Марса. Використовуючи довідкові дані, обчисліть прискорення вільного падіння на поверхні Марса. Наскільки воно менше за земне? (Маса Марса $M_M \approx 6.4 \cdot 10^{23}$ кг, радіус Марса $R_M \approx 3400$ км).
#
# **Задача 4**
# У рамках програми "Артеміда" NASA планує нові місії на Місяць. Щоб вивести супутник на низьку навколомісячну орбіту, йому потрібно надати першу космічну швидкість. Обчисліть, чому дорівнює перша космічна швидкість для Місяця. (Маса Місяця $M_{Міс} \approx 7.35 \cdot 10^{22}$ кг, радіус Місяця $R_{Міс} \approx 1740$ км).
#
# **Задача 5**
#
# Супутник зв'язку Starlink рухається по коловій орбіті на висоті 550 км. Згодом, для корекції орбіти, його двигуни переміщують його на вищу орбіту — 1100 км. У скільки разів змінилася сила гравітаційного притягання, що діє на супутник з боку Землі? Сила збільшилася чи зменшилася? (Радіус Землі $R_З = 6400$ км).
#
# **Задача 6**
#
# Астрономи відкрили екзопланету Kepler-186f, яку вважають однією з найбільш схожих на Землю. Її радіус становить приблизно $1.1$ радіуса Землі, а маса — $1.5$ маси Землі.
# 1. Обчисліть прискорення вільного падіння на поверхні Kepler-186f.
# 2. Якщо ваша маса становить 60 кг, якою буде ваша вага на цій екзопланеті? (Прискорення вільного падіння на Землі вважайте рівним $g_0 \approx 9.8 \text{ м/с}^2$).
#
# **Задача 7**
#
# Геостаціонарні супутники, які використовуються для телевізійного мовлення, "висять" над однією точкою земної поверхні. Це можливо тому, що вони рухаються по орбіті з періодом, що дорівнює періоду обертання Землі. Прискорення вільного падіння на такій орбіті значно менше, ніж на поверхні. На якій висоті над поверхнею Землі прискорення вільного падіння буде в 4 рази меншим, ніж на її поверхні? (Радіус Землі $R_З = 6400$ км).
#
# **Задача 8**
#
# Уявіть, що ви астроном, який вивчає Юпітер. За допомогою спостережень за його супутниками ви визначили, що прискорення вільного падіння на умовній "поверхні" хмар Юпітера становить $g_Ю \approx 24.8 \text{ м/с}^2$. Радіус Юпітера становить приблизно $R_Ю \approx 70000$ км. Використовуючи ці дані, виконайте те, що колись зробив Кавендіш для Землі — "зважте" Юпітер, тобто обчисліть його масу.
#
# **Задача 9**
#
# Між Землею та Місяцем існує точка (точка Лагранжа L1), в якій сили гравітаційного притягання від обох небесних тіл зрівноважують одна одну. Космічний апарат, розміщений у цій точці, буде "зависати" між ними. Знайдіть відстань від центру Землі до цієї точки. (Маса Землі $M_З \approx 81 \cdot M_{Міс}$, відстань між центрами Землі та Місяця $r \approx 384000$ км).
#
# **Задача 10**
#
# Супутники системи глобального позиціонування (GPS) обертаються навколо Землі на висоті приблизно 20 200 км.
# 1. Обчисліть швидкість, з якою рухається такий супутник по своїй орбіті.
# 2. Визначте період обертання супутника навколо Землі (час, за який він робить один повний оберт).
# (Маса Землі $M_З = 6 \cdot 10^{24}$ кг, радіус Землі $R_З = 6400$ км).
#
# **Задача 11**
#
# Астрономи активно шукають "Супер-Землі" — планети, масивніші за Землю, але легші за газових гігантів. Розглянемо гіпотетичну планету, радіус якої вдвічі більший за радіус Землі ($R_п = 2R_З$), а маса — у 10 разів більша за масу Землі ($M_п = 10M_З$).
# 1. У скільки разів прискорення вільного падіння на поверхні цієї планети більше, ніж на поверхні Землі?
# 2. У скільки разів перша космічна швидкість для цієї планети більша за першу космічну швидкість для Землі?
