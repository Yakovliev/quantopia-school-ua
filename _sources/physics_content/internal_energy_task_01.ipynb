# %% [markdown]
# *Задача: Неон масою 100 г міститься в колбі об'ємом 5,0 л. У процесі ізохорного охолодження тиск неону зменшився від 100 до 50 кПа. Визначити зміну внутрішньої енергії та температури неону.*
#
# Розв'язання:
# 1. Записуємо відомі величини:
#    - $m = 0,10$ кг
#    - $V = 5,0 \cdot 10^{-3}$ м³
#    - $p_1 = 1,0 \cdot 10^5$ Па
#    - $p_2 = 0,5 \cdot 10^5$ Па
#    - $M = 20 \cdot 10^{-3}$ кг/моль
#    - $R = 8,31$ Дж/(моль·К)
#
# 2. Для одноатомного газу зміна внутрішньої енергії визначається формулою:
#    $\Delta U = \frac{3}{2M}mR\Delta T$ або $\Delta U = \frac{3}{2}V(p_2 - p_1)$
#
# 3. Оскільки процес ізохорний (об'єм не змінюється), використовуємо другу формулу:
#    $\Delta U = \frac{3}{2}V(p_2 - p_1)$
#
# 4. Зміну температури знаходимо за формулою:
#    $\Delta T = \frac{2M\Delta U}{3mR}$
#
#
# ---
#
# **Вирішення задач**
#
# **Задача 1.**
# Неон масою $ 100 \, \text{г} $ міститься в колбі об’ємом $ 5{,}0 \, \text{л} $. Під час ізохорного охолодження тиск неону зменшується від $ 100 \, \text{kPa} $ до $ 50 \, \text{kPa} $. Знайдіть зміну внутрішньої енергії ($ \Delta U $) і температуру ($ \Delta T $).
#
# **Дано:**
# - $ m = 0{,}10 \, \text{кг} $,
# - $ V = 5{,}0 \times 10^{-3} \, \text{м}^3 $,
# - $ p_1 = 1{,}0 \times 10^5 \, \text{Па} $,
# - $ p_2 = 0{,}5 \times 10^5 \, \text{Па} $,
# - $ M = 20{,}1 \times 10^{-3} \, \text{кг/моль} $,
# - $ R = 8{,}31 \, \text{Дж/(моль} \cdot \text{К)} $.
#
# **Розв'язання:**
#
# 1. **Формула зміни внутрішньої енергії:**
#    Внутрішня енергія для одноатомного газу:
#    \[
#    \Delta U = U_2 - U_1 = \frac{3}{2} m \left( \frac{p_2 V}{M R} - \frac{p_1 V}{M R} \right).
#    \]
#
#    Підставивши:
#    \[
#    \Delta U = \frac{3}{2} V (p_2 - p_1).
#    \]
#
# 2. **Зміна температури газу:**
#    \[
#    \Delta T = \frac{2M \Delta U}{3mR}.
#    \]
#
# Результати обчислень залежать від підстановки значень із даних умови. Завдяки ізохорному процесу об'єм залишається сталим ($ V_1 = V_2 $).
#
# ---
#
# Цей матеріал дозволяє охопити поняття кількості теплоти, фазових переходів та ілюструє приклад розв'язання задачі з термодинаміки. Лекцію можна доповнити практичними прикладами з експериментальними даними.

# %% [markdown]
# # Задача. Зміна внутрішньої енергії
# Неон масою 100 г міститься в колбі об'ємом 5,0 л. У процесі ізохорного охолодження тиск неону зменшився від $100 \, \text{кПа}$ до $50 \, \text{кПа}$.
# На скільки при цьому змінилися внутрішня енергія та температура неону?
#
# ## Дано:
#
# - $m = 0.10 \, \text{кг}$
# - $V = 5.0 \cdot 10^{-3} \, \text{м}^3$
# - $p_1 = 1.0 \cdot 10^5 \, \text{Па}$
# - $p_2 = 0.5 \cdot 10^5 \, \text{Па}$
# - $M = 20 \cdot 10^{-3} \, \text{кг/моль}$
#
# - $R = 8.31 \, \text{Дж / (моль К)}$
#
# **Знайти**:
# - $\Delta U$ — ?
# - $\Delta T$ — ?

# %% [markdown]
# ---
#
# ## Розв'язання
#
# Для одноатомного ідеального газу внутрішня енергія визначається як:
#
#    $$ U = \frac{3}{2} \frac{m}{M} RT $$
#
# де:
# - $m$ — маса газу (кг);
# - $M$ — молярна маса газу (кг/моль);
# - $R$ — універсальна газова стала (Дж/(моль·К));
# - $T$ — температура газу (К).
#
# При зміні температури на $\Delta T = T - T_0$, відповідна зміна внутрішньої енергії дорівнює:
#
#    $$ \Delta U = U - U_0 = \frac{3}{2} \frac{m}{M} R T - \frac{3}{2} \frac{m}{M} R T_0 = \frac{3}{2} \frac{m}{M} R \left(T - T_0 \right) = \frac{3}{2} \frac{m}{M} R \Delta T $$
#
# Маємо таку формулу:
#
# $$ \Delta U = \frac{3}{2} \frac{m}{M} R \Delta T $$
#
# Виводимо:
#
# $$ \frac{3}{2} \frac{m}{M} R \Delta T = \Delta U $$
#
# $$ \frac{m}{M} R \Delta T = \frac{2 \Delta U}{3} $$
#
# $$ R \Delta T = \frac{2 M \Delta U}{3 m} $$
#
# Результат:
#
# $$ \Delta T = \frac{2 M \Delta U}{3 m R} $$
#
# Оскільки процес ізохорний (об'єм не змінюється):
#
# $$ V_1 = V_2 = V $$
#
# то для одноатомного газу зміна внутрішньої енергії визначається за формулою:
#
# $$ \Delta U = \frac{3}{2} p_2 V_2 - \frac{3}{2} p_1 V_1 = \frac{3}{2} (p_2 V_2 - p_1 V_1) = \frac{3}{2} V (p_2 - p_1) $$
#
# **Зміна температури** визначається за формулою:
#
# $$ \Delta T = \frac{2M \Delta U}{3mR} $$
#
# ### Обчислення
# 1. Обчислимо $\Delta U$:
#
#    $$ \Delta U = \frac{3}{2} V (p_2 - p_1) $$
#
# 2. Обчислимо $\Delta T$:
#
#    $$ \Delta T = \frac{2M \Delta U}{3mR} $$
#
# ---
#
# ## Відповідь:
# - $\Delta U = -375 \, \text{Дж}$
# - $\Delta T = -6 \, \text{К}$

# %%
# Вхідні дані
V = 5.0e-3       # м³ (5,0 л)
p1 = 1.0e5       # Па (100 кПа)
p2 = 0.5e5       # Па (50 кПа)
M = 20e-3        # кг/моль
m = 0.10         # кг
R = 8.31         # Дж/(моль·К)

# %%
# Зміна внутрішньої енергії
delta_U = (3 / 2) * V * (p2 - p1)

print(f"delta_U = {delta_U:.2f} Дж")
# Out:
# delta_U = -375.00 Дж

# %%
# Зміна температури
delta_T = (2 * M * delta_U) / (3 * m * R)

print(f"delta_T = {delta_T:.2f} K")
# Out:
# delta_T = -6.02 K

# %%
# Підсумок
print(f"Зміна внутрішньої енергії: ΔU = {delta_U:.2f} Дж")
print(f"Зміна температури: ΔT = {delta_T:.2f} К")
# Out:
# Зміна внутрішньої енергії: ΔU = -375.00 Дж
# Зміна температури: ΔT = -6.02 К
